# %% [markdown]
# # SQLite Database
#
# - Create the places for LLM import
# - Import the information from the LLMs
#
#
# Database Schema is designed as below:
#
# **EPISODES TABLE**
# ---
#
# | Column Name       | Data Type         | Description                         |
# |-------------------|-------------------|-------------------------------------
# | `episode_number`  | `INT`             | The episode number. Primary Key.    |
# | `episode_title`   | `VARCHAR(255)`     | The title of the episode.           |
# | `episode_date`    | `DATE`            | The release date of the episode.    |
# | `audio_url`       | `VARCHAR(255)`     | The URL of the episode's audio.     |
# | `description_tr`  | `TEXT`            | The episode description in Turkish. |
# | `description_en`  | `TEXT`            | The episode description in English.
#
#
# **GUESTS TABLE**
# ---
# | Column Name      | Data Type       | Description                                                       |
# |------------------|-----------------|-------------------------------------------------------------------|
# | `id`             | `SERIAL`        | Unique guest ID (auto-incrementing). Primary key.                 |
# | `episode_number` | `INT`           | Foreign key linking to the `episodes` table.                     |
# | `guest_name`     | `VARCHAR(255)`   | Guest's name (non-nullable).                                      |
#
# **KEYWORDS TABLE**
# ---
# | Column Name      | Data Type        | Description                                                       |
# |------------------|------------------|-------------------------------------------------------------------|
# | `id`             | `SERIAL`         | Unique keyword ID (auto-incrementing). Primary key.               |
# | `episode_number` | `INT`            | Foreign key linking to the `episodes` table.                     |
# | `type`           | `ENUM`           | Type of keyword (person, place_tr, subject_tr, subject_en).       |
# | `keyword_text`   | `VARCHAR(255)`    | The keyword text (e.g., person name, place, subject).             |

# %%
import sqlite3

# %%
with sqlite3.connect("nasil_olunur_database.db") as connection:
    # Create a cursor object
    cursor = connection.cursor()

    cursor.executescript('''
    CREATE TABLE IF NOT EXISTS episodes (
        episode_number PRIMARY KEY UNIQUE,
        title VARCHAR(255),
        episode_date DATE,
        audio_url VARCHAR(500),
        word_document_name VARCHAR(255),
        description_tr TEXT,
        description_en TEXT
    );
    CREATE TABLE IF NOT EXISTS guests (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        episode_number INT,
        guest_name VARCHAR(255) NOT NULL,

        CONSTRAINT unique_guest_episode UNIQUE (episode_number, guest_name),
        FOREIGN KEY (episode_number) REFERENCES episodes (episode_number) ON DELETE CASCADE
    );
    CREATE TABLE IF NOT EXISTS keywords (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        episode_number INT,
        type TEXT NOT NULL CHECK (type IN ('person', 'place_tr', 'subject_tr', 'subject_en')),
        keyword_text VARCHAR(255) NOT NULL,

        FOREIGN KEY (episode_number) REFERENCES episodes (episode_number) ON DELETE CASCADE,
        CONSTRAINT keyword_type CHECK (type IN ('person', 'place_tr', 'subject_tr', 'subject_en'))
    );
    ''')

# %% [markdown]
# ## Preparing for batch insert into the databases

# %%
from dotenv import load_dotenv
import os
import feedparser

# Load env variables from .env file
load_dotenv()
no_url = os.getenv("NO_URL")

# Getting the feed
feed = feedparser.parse(no_url)

# %%
def parse_feed(feed):
    """Parse the feed and extract key info for Episodes table"""
    data_episodes, data_guests = [], []

    for episode in feed['entries']:

        title = episode["title"]
        guest_name = get_authors(episode)
        episode_number = get_episode_number(episode)
        episode_date = get_episode_date(episode)
        audio_url = episode.enclosures[0].href

        description_tr = episode["description"]
        description_en = "N/A" #translate_to_english(description_tr)

        data_episodes.append((
            episode_number,
            title,
            episode_date,
            audio_url,
            description_tr,
            description_en
        ))
        data_guests.append((
            episode_number,
            guest_name
        ))

    return data_episodes, data_guests

# %%
parse_feed(feed)
# Out:
# ([(243,
#    '243- Osman Ulagay',
#    '10/07/2025',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes
#    'N/A'),
#   (241,
#    '241- Hüseyin Kıyak',
#    '12/06/2025',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes/82ac88cd-1c58-4aac-9d36-003b52224aad/audio/e247bfbb-0773-4a67-89ef-888381ed23df/default_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Nasıl Olunur’un bu bölümünde konumuz Klasik Türk Müziği, konuğum müziğin icracısı, akademisyen, yazar ve araştırmacı Hüseyin Kıyak. \nHüseyin ile Türk Sanat Müziği’nin dününden bugününe, notasından makamına pek çok konu konuştuk. Sohbetimizden bazı konu başlıkları…\n\n•\tKlasik Türk Müziği, Türk Sanat Müziği, Osmanlı / Türk musikisi, musiki… Adı ne?\n•\tBu müziğin altın dönemi ne zamandı? Bugün nerede? Bu müzik başka müzikler için de yaşıyor mu?\n•\tMakam, güfte, güfte mecmuaları, şarkı, çeşni; bunlar neler?\n•\tKlasik Türk Müziği’nde eski dönemlere dair kaynak azlığının nedenleri neler?\n•\tBu müziği bugünlere kadar taşıyan belli başlı isimler ya da olaylar neler?\n•\tNinninin de bir makamı var, ezanın da…\n•\tBir Türk Sanat Müziği sanatçısının olmazsa olmazları nelerdir?\n•\tKonservatuarın kuruluşu, 1926’da Klasik Türk Müziği Eğitimi’nin kaldırılışı ve tüm bunların etkileri\n•\tMüzikte plak, radyo ve televizyon dönemi…\n•\tBir makamı nasıl tanırız?',
#    'N/A'),
#   (240,
#    '240- Soner Çağaptay',
#    '22/05/2025',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes/698938e0-58a0-49ca-bde6-79d7e887e4e0/audio/a10f8253-f5cc-4fee-b330-7e2d42baf2cf/default_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Bu bölümde konuğum bir siyasi analist, yazar ve tarihçi Soner Çağaptay.\nBaşlıca çalışma alanları Türkiye-ABD ilişkileri, Türk iç politikası ve Türk milliyetçiliği olan, bu konudaki metin ve kitaplarının yanı sıra Recep Tayyip Erdoğan üzerine de üç kitabı olan Çağaptay ile 19 Mart süreci, öncesi ve sonrasını konuştuk...\nTürkçe\xa0ve\xa0İngilizce\xa0dışında,\xa0Almanca,\xa0Fransızca,\xa0Osmanlıca, İspanyolca,\xa0Boşnakça,\xa0İbranice\xa0ve Azerice de bilen Çağaptay\'a "Bu kadar yabancı dil nasıl öğrenilir?"sorusunu da yönelttim. Darüşşafaka\'ya ayrı bir parantez açtık. \n\nBazı başlıkları da sıralarsak...\n* Bir "Rekabetçi\xa0Otoriter\xa0Rejim" içinde miyiz? Yoksa artık sadece otoriter dönemde miyiz?\n* Kültürel hegemonya hangi yönde?\n* Eğitimli kesimde AKP\'ye destek ne düzeyde?\n* "Atatürk\'ün rüyası Erdoğan döneminde gerçekleşti" ifadesinin açılımı...\n* Yine yeniden sahiplenilen Atatürk.\n* Kimler, Mustafa Kemal Atatürk\'ün hangi dönemini sahipleniyor?\n* Gençlerin bu dönemdeki rolü...\n* ABD-Türkiye ilişkileri\n* Malatya doğumlu yoksul bir işçi ailesinin 7 çocuğu nasıl bu kadar eğitimli insanlar oldular?',
#    'N/A'),
#   (239,
#    '239- Mabel Matiz',
#    '08/05/2025',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes
#    'N/A'),
#   (221,
#    '221- Nedim Saban',
#    '11/07/2024',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes/a92bd969-abc7-4b4c-99a4-6478c7b46071/audio/95250ed5-257f-46ab-b3ba-b78e255091c1/default_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    "sıra televizyon için de metinler yazmış, dizi ve filmlerde rol almış bir isim.\nAkademik bir tarafı, eğitimciliği de var. Saban ile tiyatro ve izleyiciler üzerinden bugünü, toplumu, oyun oynamayı, vefayı ve daha bir çok konuyu konuştuk. Sıkça 90'ları andığımız bölümde, Dr. Stress'ten Saklambaç'a, New York'taki çiğ köfte partisinden Danny Devito'nun dublörlüğüne enteresan konuları da kayda aldık.",
#    'N/A'),
#   (220,
#    '220- Ezgi Mola',
#    '25/06/2024',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes/e68d920b-ca37-4c84-b274-53fd232576c9/audio/1cdb0421-6c4a-49d6-8397-c308947c0b23/default_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Bu bölümde konuğum oyuncu Ezgi Mola. \nEzgi ile sohbete çocukluk döneminde yaşadığı bazı güçlüklerden, hayallerinden ve bu hayalleri gerçekleştirme yolunda okulunun, kişiliğinin, çalışkanlığının etkisinden konuşarak başladık. Kadın komedi ya da dram oyuncusu olmak, kilo değişimleriyle yaşanan rol dengesi, doğru yerde doğru tavır koymanın özgürleştirici etkisi, annelik, dostluklar, takıntılar, hayranlıklar ve daha pek çok konu... Yüzünüze bir gülümseme yayacak öğretici bir sohbet dinlemeye hazır olun.',
#    'N/A'),
#   (219,
#    '219- Ayşegül Aldinç',
#    '12/06/2024',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes/f402de0e-c3e4-47d7-b306-d74aa3ce8497/audio/99e0820c-b9d5-4a39-84dc-f0fc9b6f3d8e/default_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    "Bu bölümde konuğum Ayşegül Aldinç. Şarkıcılığı, oyunculuğu, köşe yazıları ve kitaplarıyla yıllardır hayatımızda.\nZamanının ötesinde, farklı, akılda ve kulakta kalan, alternatif bir sanatçı... Ayşegül Aldinç ile hem onun seramik sanatçılığından Eurovision günlerine, Barış Manço dokunuşu ile 'rocker girl' imajından efsanevi kliplerine geçmiş günlerinden bahsettik hem de bugünü onun gözünden değerlendirdik... Su gibi akan bir Nasıl Olunur bölümü sizleri bekliyor.",
#    'N/A'),
#   (218,
#    '218 - Buket Uzuner',
#    '28/05/2024',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes/630a0f69-b86a-4c98-9adc-b38435134ec4/audio/2a12742c-e164-48ea-9dd8-4a84e3d25344/default_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Bu bölümde konuğum yazar Buket Uzuner.\nÖğretim üyeliği de yapmış bir biyolog ve gezgin olan Uzuner ile sohbete ailesinden, özellikle de annesinden konuşarak başladık. Çocuklarına aşureyi Nuh\'un Gemisiyle anlatan, yıldızları öğreten, hayaller kurduran bir anne... \nBuket Uzuner ile eserlerini yazma ve araştırma sürecini, "mesele edinme" meselesini, rol modellerini, tarihteki kadınlara iade-i itibarı, doğayla, köklerimizle ilişkilerimizi ve daha pek çok konuyu konuştuk. Bilinç akışıyla ilerleyen, öğreten, dirilten bir sohbete hazır olun.',
#    'N/A'),
#   (217,
#    '217 - Mahir Polat',
#    '14/05/2024',
#    'https://cdn.simplecast.com/audio/41de0602-25fb-46f9-8041-964fa58ffcaa/episodes
2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/bf9d3e64-9f15-453e-b05f-6f7a6915cd68/13_Nasil_Olunur_Basar_Basaran_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Televizyon dizileri ülkemiz kültürünün vazgeçilmez bir parçası. Senarist ve yazar Başar Başaran ile yazarlık tecrübesine ve ülkemizdeki televizyon dünyasına ve izleyici alışkanlıklarına dair keyifli bir sohbet Nilay Örnek’in hazırlayıp sunduğu Nasıl Olunur’da sizleri bekliyor.',
#    'N/A'),
#   (12,
#    '12- Aylin Aslım',
#    '17/05/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/7e575ac7-4495-4504-827f-777a005704ca/12_Nasil_Olunur_Aylin_Aslim_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Rock müziğin en önemli kadın seslerinden, şarkı yazarı Aylin Aslım, bu bölümde Nilay Örnek’e konuk oluyor. Kendi müzik kariyerinden, Türkiye’deki müzik dünyasına; yaşadığı zorluklardan başarılarına Aylin Aslım ile bu keyifli sohbeti kaçırmayın.',
#    'N/A'),
#   (11,
#    '11- Berk İmamoğlu',
#    '30/04/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/0d53969f-fa1a-4f71-b15a-865fe9250634/11_Nasil_Olunur_Berk_Imamoglu_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    '11’inci bölümde Nasıl Olunur’a Berk İmamoğlu konuk oluyor. Seslenen Kitap’ı kurarak dünyada çok sevilen sesli kitapları Türkiye’ye tanıtan Berk İmamoğlu’nun, Seslenen Kitap’tan Storytel’e uzanan zorlu ama başarılı macerasını anlattığı bölümde, Türkiye’deki girişimcilik dünyasına ve yaşanan dijital dönüşüme dair ufuk açıcı ve öğretici ipuçları bulmak mümkün.',
#    'N/A'),
#   (10,
#    '10- Saadet Özen',
#    '29/04/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/0e19d506-7c0d-4b5f-b007-1bd5793c8c23/10_Nasil_Olunur_Saadet_Ozen_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Nilay Örnek, Nasıl Olunur’un 10’uncu bölümde Saadet Özen’i konuk ediyor. Fernando Pessoa ve Jose Saramago gibi birçok önemli yazarın eserlerini Türkçe’ye kazandırmasının yanı sıra eğitimli bir arkeolog olan, İstanbul ve tarihle ilgili çalışmalarıyla da tanınan Saadet Özen ile profesyonel yaşamının tüm bu farklı alanlarına dokunan keyifli bir sohbet bu bölümde sizlerle.',
#    'N/A'),
#   (9,
#    '9: Mehmet Yaşin',
#    '29/04/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/e6d43152-2375-429b-8805-8ba40daafc89/9_Nasil_Olunur_Mehmet_Yasin_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Nilay Örnek’in bu bölümdeki konuğu gazeteci, yazar, gezgin ve “şikemperver” Mehmet Yaşin. ABD’de geçen yıllarından savaş muhabirliğine, Atlas Dergisi’nin kuruculuğundan Türkiye’nin en sevilen yemek programcılarından biri olmasına; Mehmet Yaşin’le dopdolu geçen yaşamına ve kariyerine dair çok içten ve sıcak bir sohbet sizi bekliyor.',
#    'N/A'),
#   (8,
#    '8: Levent Erden',
#    '16/04/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/62624573-2d6b-4133-adcc-8051fd0df7d9/8_Nasil_Olunur_Levent_Erden_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    '8. Bölümü’nde Nasıl Olunur’un konuğu Türkiye’de pazarlama denince ilk akla gelen isimlerden Levent Erden. Reklamcılığının yanı sıra yazar, eğitimci, konuşmacı ve televizyoncu olarak birçok önemli projeye imza atmış olan Erden, bugünün dünyasına dair zihin açıcı yorumlarını paylaşırken, zamanın ruhunu anlamımıza ve başa çıkmamıza yardımcı olacak ipuçları veriyor.',
#    'N/A'),
#   (7,
#    '7: Vedat Ozan',
#    '16/04/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/b2f9d067-265d-487f-bfe1-5e6d03344db9/7_Nasil_Olunur_Vedat_Ozan_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Nasıl Olunur’un 7. Bölümü’nde konuk, parfümör, koku uzmanı ve yazar Vedat Ozan. Türkiye’de kokuların dünyasını ve gizemini en iyi bilenlerden biri olan Ozan’dan pek çok ilginç bilgi edinebileceğiniz bu bölümde, insanın yaşamsal deneyiminin en önemli parçalarından biri olan koku duyusuna hiç bakmadığınız bir gözle bakacaksınız.',
#    'N/A'),
#   (6,
#    '6: Can Öz',
#    '16/04/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/7b98d808-4d29-46d7-9788-ab4eb83268b6/6_Nasil_Olunur_Can_Oez_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    "Nilay Örnek’in hazırlayıp sunduğu Nasıl Olunur’un 6. Bölümü’nün konuğu Can Yayınları'nın Yönetim Kurulu Başkanı ve Socrates Dergisi’nin genel müdürü Can Öz. Kitap ve dergi yayıncılığı konusundaki benzersiz tecrübesini aktaran Öz’ün, yayınevi yöneticiliğinden, yazarlığa; kitapların ekonomisinden, değişen yayıncılık dünyasına birçok önemli ipucu ve bilgiyi paylaştığı bu keyifli sohbeti sakın kaçırmayın.",
#    'N/A'),
#   (5,
#    '5: Murat Meriç',
#    '28/03/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/8370d3d1-3aad-41fb-ae4f-2339463d93cf/Nasil_Olunur_05_Murat_Meric_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'Bu bölümün konuğu; basılı medyadan, radyo ve televizyona kadar her mecrada yer almış, belgesellere danışmanlık yapmış, müzik dünyamızdaki yeri tartışılmaz bir isim olan müzik yazarı Murat Meriç. Meriç’in yazar ve müzik araştırmacısı kimliğinden başlayan sohbet, Türkiye’nin müzikli tarihine, ülkemiz tarihini eserleriyle anlatan müzisyenlere, dünün ve bugünün müziğine uzanıyor. Zeki Müren’den Ezhel’e, Mazhar Alanson’dan Barış Manço’ya; müzikle ve müzisyenlerle dolu renkli bir sohbet bu bölümde sizleri bekliyor.',
#    'N/A'),
#   (4,
#    '4: İbrahim Selim',
#    '28/03/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/01fe372b-6286-4b2f-979d-369e79e6f4a4/Nasil_Olunur_04_Ibrahim_Selim_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'İbrahim Selim, kendi neslinin en yetenekli aktörlerinden biri olmasının yanında, aynı anda bir tiyatro oyunu ve müzikalde rol alan, seslendirme yapan, online mecrada çok popüler işlere imza atan, tv ve sinema projelerinde yer alan, tam anlamıyla çok yönlü ve skalası geniş bir oyuncu. Bu bölümde, mesleği haricinde de söyleyecekleri olan İbrahim Selim’le oyunculuktan başlayıp toplumun bugünkü hallerine de evrilen keyifli bir sohbet sizleri bekliyor.',
#    'N/A'),
#   (3,
#    '3: İsmail Küçükkaya',
#    '28/03/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/0c41799f-fb19-4d59-ac0f-06f16f931f24/Nasil_Olunur_03_Ismail_Kucukkaya_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    "Hafta içi her sabah Fox TV'de Çalar Saat'i hazırlayıp sunan, Türkiye’nin en çok izlenen habercilerinden İsmail Küçükkaya, Nilay Örnek’e konuk oluyor. Basılı medyadan televizyon haberciliğine geçiş sürecini ve mesleki yolculuğunu anlatan Küçükkaya ile Türkiye medyasına dair çok özel anekdotlar sizleri bekliyor. Kendisine yöneltilen eleştirilerden, seçim gecesi yaşanan tartışmalara; Küçükkaya birçok farklı konuda samimi düşüncelerini paylaşıyor. İsmail Küçükkaya ile gazetecilik, siyaset ve günümüz Türkiye’sine dair ilgi çekici ve farklı bir sohbet sizlerle.",
#    'N/A'),
#   (2,
#    '2: Zeynep Atakan',
#    '28/03/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/50fd9162-e2fd-4f05-af76-97f2e248f091/Nasil_Olunur_02_Zeynep_Atakan_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    "Bu bölümde, ülkemizde 'bağımsız film yapımcılığı' denilince ilk akla gelen isimlerin başında gelen, Nuri Bilge Ceylan filmlerinin yapımcısı ve Türkiye’nin uluslararası anlamda en başarılı ve tanınan sinemacılarından Zeynep Atakan ile film yapımcılığına dair benzersiz bir sohbet sizi bekliyor. Bu sohbetle bir film yapmak için oluşması gereken şartlardan iyi bir yapımcının hangi özelliklere sahip olması gerektiğine pek çok konuda bilgi edinebilirsiniz. Zeynep Atakan, uzun yılların birikiminden damıttığı önerileri bu podcast'te özetliyor...",
#    'N/A'),
#   (1,
#    '1: Serdar Kuzuloğlu',
#    '28/03/2019',
#    'https://cdn.simplecast.com/audio/41de06/41de0602-25fb-46f9-8041-964fa58ffcaa/e71cc7fe-5b12-4be6-a7e3-13836e9b6904/Nasil_Olunur_01_Serdar_Kuzuloglu_tc.mp3?aid=rss_feed&feed=TRRbx_5C',
#    'İkizleri yeni dünyaya gelmişti, bir purosu ve 34 TL\'si kalmıştı... Sonra neler oldu? Televizyon ve radyo programlarının en çok takip edilen ve aranan konuklarından, başta teknoloji ve değişen dünya olmak üzere birçok konuda ülkemizin en sevilen konuşmacılarından biri olan Serdar Kuzuloğlu, "usta konuşmacılığa"; giden kendi profesyonel macerasını, yaşadığı zorlukları ilk kez anlatıyor.',
#    'N/A')],
#  [(243, ['Osman Ulagay']),
#   (242, ['Ergin İren']),
#   (241, ['Hüseyin Kıyak']),
#   (240, ['Soner Çağaptay']),
#   (239, ['Mabel Matiz']),
#   (238, ['Tilbe Saran']),
#   (237, ['Emre Zeytinoğlu']),
#   (236, ['Ayşen Zamanpur']),
#   (235, ['Diler Acar']),
#   (234, ['Banu ÇIftçI']),
#   (233, ['Erdal Erzincan']),
#   (232, ['Can Bonomo']),
#   (231, ['Nezaket Erden', 'Hakan Emre Ünal']),
#   (230, ['Adnan Bali']),
#   (229, ['Ayşe Zarakol']),
#   (228, ['Safa Şahin']),
#   (227, ['Fırat Neziroğlu']),
#   (226, ['İoanna Kuçuradi']),
#   (225, ['Mehmet Sinan Kuran']),
#   (224, ['Kazım Gürel']),
#   (223, ['Tamer Yılmaz']),
#   (222, ['Ümit Ünal']),
#   (221, ['Nedim Saban']),
#   (220, ['Ezgi Mola']),
#   (219, ['Ayşegül Aldinç']),
#   (218, ['Buket Uzuner']),
#   (217, ['Mahir Polat']),
#   (216, ['Özge Fışkın']),
#   (215, ['Emrah Yücel']),
#   (214, ['Gülsün Karamustafa']),
#   (213, ['Utku Ergin']),
#   (212, ['Kalben Sağdıç']),
#   (211, ['Jülide Ateş']),
#   (210, ['Süreyya Ciliv']),
#   (209, ['Yağmur Taylan', 'Durul Taylan']),
#   (208, ['Serkan Keskin']),
#   (207, ['Salim Kadıbeşegil']),
#   (206, ['Dilek Gürsoy']),
#   (205, ['Mete Atatüre']),
#   (204, ['Bünyamin Aydın']),
#   (203, ['Murat Germen']),
#   (202, ['Deniz Yüce Başarır']),
#   (201, ['Çağan Irmak']),
#   (200, ['Berk İmamoğlu', 'Serdar Kuzuloğlu']),
#   (199, ['Erol Evgin']),
#   (198, ['Hasan Çalışlar']),
#   (197, ['Gülten Dayıoğlu']),
#   (196, ['Fatih Akerdem']),
#   (195, ['Zuhal Olcay']),
#   (194, ['İbrahim Betil']),
#   (193, ['Timuçin Oral']),
#   (192, ['Ahmet San']),
#   (191, ['Feride Çiçekoğlu']),
#   (190, ['Uğurcan Ataoğlu']),
#   (189, ['Fırat İşbecer']),
#   (188, ['Cem Bölükbaşı']),
#   (187, ['Sadriye Görece']),
#   (186, ['Filiz Ali']),
#   (185, ['Celal Abdi Güzer']),
#   (184, ['Enis Ayar']),
#   (183, ['Meltem Şenol Balaban', 'Osman Balaban']),
#   (182, ['Beral Madra']),
#   (181, ['Gülse Birsel']),
#   (180, ['Prof Dr Dilek Oğuz']),
#   (179, ['Fatih Sütçü']),
#   (178, ['Şahika Ercümen']),
#   (177, ['Ata Demirer']),
#   (176, ['Turgut Kazan']),
#   (175, ['Kenan Doğulu']),
#   (174, ['Ferda Keskin']),
#   (173, ['Nurcan Akad']),
#   (172, ['Yankı Yazgan']),
#   (171, ['Okan Bayülgen']),
#   (170, ['Serra Yılmaz']),
#   (169, ['Hüseyin Çağlayan']),
#   (168, ['Ayşe Kulin']),
#   (167, ['Bülent Şık']),
#   (166, ['Ebru Boyar', 'Prof. Dr. Ebru Boyar.']),
#   (165, ['Semih Saygıner']),
#   (164, ['Emre Alettin Keskin']),
#   (163, ['Bartu Bölükbaşı']),
#   (162, ['Zahit Mungan']),
#   (161, ['Prof. Dr. Cem Terzi']),
#   (160, ['Mehmet Akdağ']),
#   (159, ['Teoman']),
#   (158, ['Nazan Kesal']),
#   (157, ['Metin Akpınar']),
#   (156, ['Bülent Ortaçgil']),
#   (155, ['Faruk Pekin']),
#   (154, ['Latife Tekin']),
#   (153, ['Tuncay Birkan']),
#   (152, ['Mert Gökalp']),
#   (151, ['Esin Aydemir Kasa']),
#   (150, ['Ali Ekber Yıldırım']),
#   (149, ['Hatice Aslan']),
#   (148, ['Prof. Dr. Rüstem Aslan']),
#   (147, ['İskender Sayek']),
#   (146, ['Armağan Çağlayan']),
#   (145, ['Burçin Acer']),
#   (144, ['Oğuz Öner']),
#   (143, ['Ayfer Tunç']),
#   (142, ['Sedat Anar']),
#   (141, ['Sevin Okyay']),
#   (140, ['Türker Kılıç', 'Prof. Dr. Türker Kılıç']),
#   (139, ['Hakan Atala']),
#   (138, ['Gülşat Aygen']),
#   (137, ['Aldulhalim Demir']),
#   (136, ['Arif Keskiner']),
#   (135, ['Judith Malika Liberman']),
#   (134, ['Seçkin Pirim']),
#   (133, ['Serkan Angı']),
#   (132, ['Emre Kongar']),
#   (131, ['Belkıs Akkale']),
#   (130, ['Cem Yılmaz']),
#   (129, ['Oktay Çetinkaya']),
#   (128, ['Gürbüz Doğan Ekşioğlu']),
#   (127, ['Beliz Güçbilmez']),
#   (126, ['İlker Küçükparlak']),
#   (125, ['Jilber Bartuçiyan']),
#   (124, ['Cihan Erdönmez']),
#   (123, ['Hakan Doğan']),
#   (122, ['Simay Bülbül']),
#   (121, ['Nevzat Sayın']),
#   (120, ['Hande Kazanova']),
#   (119, ['Ahmet Mümtaz Taylan']),
#   (118, ['M.K.Perker']),
#   (117, ['Ebru Baybara Demir']),
#   (116, ['Zülfü Livaneli']),
#   (115, ['Mehmet Açar']),
#   (114, ['Koray Birand']),
#   (113, ['Cem Mansur']),
#   (112, ['Işık Güner']),
#   (111, ['Can Kozanoğlu']),
#   (110, ['Hünkâr Mehmet Çalışkan']),
#   (109, ['Yasemin Giritli İnceoğlu']),
#   (108, ['Levent Kazak']),
#   (107, ['Mehmet Çağçağ']),
#   (106, ['Hazal Kaya']),
#   (105, ['Bahar Özgüvenç', 'Fatma Şahin']),
#   (104, ['Engin Yılmaz']),
#   (103, ['Nükhet Duru']),
#   (102, ['Lale Mansur']),
#   (101, ['Rüstem Batum']),
#   (100, ['Serdar Kuzuloğlu']),
#   (99, ['Gökhan Akçura']),
#   (98, ['Ömer Madra']),
#   (97, ['Nesrin Topkapı']),
#   (96, ['Gamze Cizreli']),
#   (95, ['Dr. Agâh Aydın']),
#   (94, ['Akın Öngör']),
#   (93, ['Oya Baydar']),
#   (92, ['Kaan Kural']),
#   (91, ['Ahu Serter']),
#   (90, ['Coşkun Aral']),
#   (89, ['Bager Akbay']),
#   (88, ['Aydın Engin']),
#   (87, ['Süleyman Özyıldırım (Shades)']),
#   (86, ['İclal Aydın']),
#   (85, ['Naci Görür']),
#   (84, ['Emin Yoğurtçuoğlu']),
#   (83, ['Ünsal Ünlü']),
#   (82, ['Ümmiye Koçak']),
#   (81, ['Ercan Kesal']),
#   (80, ['Talat Kırış']),
#   (79, ['Nejat Yavaşoğulları']),
#   (78, ['Beyza Yavuz']),
#   (77, ['Şebnem Uyar']),
#   (76, ['Mustafa Yurtbulmuş', 'Elif Keskin Yurtbulmuş']),
#   (75, ['Yılmaz Erdoğan']),
#   (74, ['Ahmet Şenol']),
#   (73, ['Uğur Tanyeli']),
#   (72, ['Gönül Öney']),
#   (71, ['Levent Kömur']),
#   (70, ['Bülent Eczacıbaşı']),
#   (69, ['Gündüz Vassaf']),
#   (68, ['Tuğçe Tez']),
#   (67, ['Metin Yüksek', 'Taşkın Yüksek']),
#   (66, ['Mustafa Oğuz']),
#   (65, ['Tanıl Bora']),
#   (64, ['Emrah Çoraman']),
#   (63, ['Tuğrul Eryılmaz']),
#   (62, ['Sinan Güler']),
#   (61, ['Ece Temelkuran']),
#   (60, ['Fem Güçlütürk']),
#   (59, ['Mehmet Atakan Foça']),
#   (58, ['Erdil Yaşaroğlu']),
#   (57, ['Sinan Hamamsarılar']),
#   (56, ['Şermin Yaşar']),
#   (55, ['Nazım Tanrıkulu']),
#   (54, ['Derya Bengi']),
#   (53, ['Hüsamettin Koçan']),
#   (52, ['Selami Şahin']),
#   (51, ['Nurten Öztürk']),
#   (50, ['Emre Arolat']),
#   (49, ['Harun Tekin']),
#   (48, ['Murathan Mungan']),
#   (47, ['Uğur Gürses']),
#   (46, ['Yetkta Kopan']),
#   (45, ['Berrin Bal Onur', 'Neşe Aksoy Biber']),
#   (44, ['Saffet Emre Tonguç']),
#   (43, ['Ferhat Aydin']),
#   (42, ['Nisan Ak']),
#   (41, ['Evrim Kuran']),
#   (40, ['Bahattin Duran']),
#   (39, ['Arzu Kaprol']),
#   (38, ['Serdar Erener']),
#   (37, ['Doğan Cüceloğlu']),
#   (36, ['Ahmet Uluğ']),
#   (35, ['Nihat Sırdar']),
#   (34, ['Jared Wall']),
#   (33, ['Haluk Oral']),
#   (32, ['İsmail Gezgin']),
#   (31, ['Tarık Bayazıt', 'Savaç Ertunç']),
#   (30, ['Mehmet Y. Yılmaz']),
#   (29, ['Hasan Söylemez']),
#   (28, ['Rayka Kumru']),
#   (27, ['Can Gürses']),
#   (26, ['Bekir Ağırdır']),
#   (25, ['Şokopop']),
#   (24, ['Nevzat Aydın']),
#   (23, ['Dilara Koçak']),
#   (22, ['Murat Daltaban', 'Özlem Daltaban']),
#   (21, ['Mesut Süre']),
#   (20, ['Emrah Ablak']),
#   (19, ['Meriç Eryürek']),
#   (18, ['İnci Eviner']),
#   (17, ['Fatih Altınöz']),
#   (16, ['İlker Canikligil']),
#   (15, ['Mert Fırat']),
#   (14, ['Selçuk Şi̇rin']),
#   (13, ['Başar Başaran']),
#   (12, ['Aylin Aslım']),
#   (11, ['Berk İmamoğlu']),
#   (10, ['Saadet Özen']),
#   (9, ['Mehmet Yaşin']),
#   (8, ['Levent Erden']),
#   (7, ['Vedat Ozan']),
#   (6, ['Can Öz']),
#   (5, ['Murat Meriç']),
#   (4, ['İbrahim Selim']),
#   (3, ['İsmail Küçükkaya']),
#   (2, ['Zeynep Atakan']),
#   (1, ['Serdar Kuzuloğlu'])])

# %%
import re

def get_authors(episode: feedparser.util.FeedParserDict) -> list[str]:
    """Return guest names in a given episode"""
    exclude_names = {"Storytel", "Nilay Örnek", "Nasıl Olunur?"}
    episode_names = [name.strip().title() for name in episode.author.split(', ')]
    authors = list(filter(lambda guest: guest not in exclude_names, episode_names))

    # If episode has no assigned authors in the RSS feed,
    # extract authors from episode title
    if len(authors) == 0:
        title = episode.title
        dash_pos = title.find("-")
        shortened_title = title[dash_pos+1:].strip()
        authors = [name.strip() for name in re.split(r'-|,|\\', shortened_title)]

    return authors

# ep = feed.entries[130]
# get_authors(ep)

# %%
def get_episode_number(episode: feedparser.util.FeedParserDict) -> int:
    """Return the episode number of a given episode"""
    title = episode.title
    episode_number = int(re.split('-|:', title)[0].strip())
    return episode_number

# ep = feed.entries[156]
# print(ep.title)
# get_episode_number(ep)

# %%
from deep_translator import DeeplTranslator

def translate_to_english(description: str) -> str:
    """Return the English translation of an episode description"""
    # return GoogleTranslator(source='turkish', target='en').translate(description)
    key = os.getenv("DEEPL_API_KEY")
    return DeeplTranslator(
        api_key=key,
        source="tr",
        target="en"
    ).translate(description)

# ep = feed.entries[0].description
# translate_to_english(ep)
# Out:
# /Users/kaanerdem/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %%
import time

def get_episode_date(episode) -> str:
    """Return the date of an episode in string format"""
    episode_date = time.struct_time(episode.published_parsed)
    return time.strftime("%d/%m/%Y", episode_date)

# ep = feed.entries[0]
# get_episode_date(ep)

# %% [markdown]
# Yapilabilecek gelistirmeler:
# - Ingilizce translationlar tek bir yerde kalsin ya da cachele bi sekilde, surekli api call gelmesin. Hem para hem zaman israfi.
# - Belki sql query'si yapip translation fonksiyonunda, eger entry varsa var olan entry'yi gecerim.
# Figure out how database primary and secondary keys work.
# Understand how your database tables would be working like.
#
# Populate your database. YAPTIM !
#
# Figure out how to use the LLM.

# %%
def populate_database_tables() -> None:
    """Populate the database with existing information from the RSS Feed"""

    with sqlite3.connect("nasil_olunur_database.db") as connection:
        cursor = connection.cursor()
        data_episodes, data_guests = parse_feed(feed)

        cursor.executemany("""INSERT OR REPLACE INTO episodes (
                                episode_number,
                                title,
                                episode_date,
                                audio_url,
                                description_tr,
                                description_en
                                )
                            VALUES(?,?,?,?,?,?)""", data_episodes)

        # `data_guests` contains tuples like (episode_number, [guest_names])
        for episode_number, guests in data_guests:
            for guest in guests:
                cursor.execute("""INSERT OR IGNORE INTO guests (episode_number, guest_name) VALUES (?, ?)""", (episode_number, guest))

# %%
populate_database_tables()

# %% [markdown]
# ## Keyword Extraction with LLM
#
# - setup langchain
# - experiment with result
# - store in correct format. upload it to the db

# %%
from docx import Document

def get_docx_text(file_path):
    """Returns document episode number & text."""
    try:
        # episode_no = file_path[file_path.find("new_episodes/")+13:file_path.find("-")].strip()
        episode_no = int(file_path[file_path.find("new_episodes/")+13:file_path.find("-")].strip())
        doc = Document(file_path)
        return episode_no, "\n".join([para.text for para in doc.paragraphs])
    except Exception as e:
        print(f"Exception reading {file_path}: {e}")

# %%
import os
from openai import OpenAI
from pydantic import BaseModel

load_dotenv(dotenv_path=".env", override=True)

OPENAI_API_KEY = os.getenv("OPENAI_API_KEY")
client = OpenAI(api_key=OPENAI_API_KEY)

# %%
# Fonskiyonun outputunu structured data extraction formatinda yazacagim.
def extract_keywords(text, model="gpt-4o-mini"):
    # Class for declaring structured data
    class EpisodeKeywords(BaseModel):
        kisiler: list[str]
        yerler: list[str]
        konular: list[str]
        konular_en: list[str]

    prompt = """
    Deneyimli bir editörsün. Görevin, sana verilen metni okuyup, anlayıp, metinde geçen en önemli anahtar kelimeleri listelemek.

    Sana verilen metin içinden en önemli 20-30 anahtar kelimeyi listelemeni istiyorum. Anahtar kelimeleri listelerken, kişi, yer ve konu/mevzu kavramları üzerinden düşünmeni, belirttiğin her anahtar kelimeyi bu başlıklardan biriyle eşleştirmeni istiyorum.

    Anahtar kelimeleri 4 ayrı liste halinde sunacaksin.
    1. liste, anahtar kişi adlarını barındıracak.
    2. liste, anahtar yer adlarını barındıracak.
    3. liste, anahtar konu/mevzuları barındıracak.
    4. liste, anahtar konu/mevzularin Ingilizce tercumelerini barindiracak
    """
    try:
        print("my api key was: {}".format(OPENAI_API_KEY))
        completion = client.beta.chat.completions.parse(
            model=model,
            messages=[
                {"role": "system", "content": prompt},
                {"role": "user", "content": text}
            ],
            response_format=EpisodeKeywords
        )
        keywords = completion.choices[0].message.parsed
        return keywords
    except Exception as e:
        print(f"Error with OpenAI API -> {e}")

# %%
# Recording API returns into DB

def format_keyword_output(episode_number:int, keywords:list[str]):
    keyword_data = []

    for keyword_type, keyword_list in [
        ("person", keywords.kisiler),
        ("place_tr", keywords.yerler),
        ("subject_tr", keywords.konular),
        ("subject_en", keywords.konular_en)
    ]:
        keyword_data.extend((episode_number, keyword_type, keyword) for keyword in keyword_list)

    return keyword_data


def write_to_keyword_table(episode_number:int, keywords:list[str]):
    """Inserts data into the keywords table."""

    keyword_tuples = format_keyword_output(episode_number, keywords)

    with sqlite3.connect("nasil_olunur_database.db") as connection:
        cursor = connection.cursor()
        cursor.executemany("""
            INSERT OR IGNORE INTO keywords(
                episode_number,
                type,
                keyword_text
                )
                VALUES(?,?,?)""", keyword_tuples)

# %%
# directory = "transcripted_episodes/episodes_with_timestamps/new_episodes"

for filename in os.listdir(directory):
    if filename.endswith(".docx"):
        ep_no, text = get_docx_text(os.path.join(directory, filename))
        print(f"Started getting keywords for Episode -> {ep_no}")
        keywords = extract_keywords(text)
        print(f"Finished getting keywords for Episode -> {ep_no}")
        write_to_keyword_table(ep_no,keywords)
        print(f"Finished writing keywords of -> {ep_no} into the table!")
        print("------------------------------")
# Out:
# Started getting keywords for Episode -> 243
# my api key was: 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
# Finished getting keywords for Episode -> 243
# Finished writing keywords of -> 243 into the table!
# ------------------------------
# Started getting keywords for Episode -> 236
# my api key was: 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
# Finished getting keywords for Episode -> 236
# Finished writing keywords of -> 236 into the table!
# ------------------------------
# Started getting keywords for Episode -> 239
# my api key was: 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
# Finished getting keywords for Episode -> 239
# Finished writing keywords of -> 239 into the table!
# ------------------------------
# Started getting keywords for Episode -> 237
# my api key was: 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
# Finished getting keywords for Episode -> 237
# Finished writing keywords of -> 237 into the table!
# ------------------------------
# Started getting keywords for Episode -> 241
# my api key was: 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
# Finished getting keywords for Episode -> 241
# Finished writing keywords of -> 241 into the table!
# ------------------------------
# Started getting keywords for Episode -> 235
# my api key was: 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
# Finished getting keywords for Episode -> 235
# Finished writing keywords of -> 235 into the table!
# ------------------------------
# Started getting keywords for Episode -> 242
# my api key was: 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
# Finished getting keywords for Episode -> 242
# Finished writing keywords of -> 242 into the table!
# ------------------------------
# Started getting keywords for Episode -> 240
# my api key was: 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
# Finished getting keywords for Episode -> 240
# Finished writing keywords of -> 240 into the table!
# ------------------------------
# Started getting keywords for Episode -> 238
# my api key was: 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
# Finished getting keywords for Episode -> 238
# Finished writing keywords of -> 238 into the table!
# ------------------------------
